# %%
import pandas as pd

df = pd.read_csv("/Users/stepanpelc/Desktop/Uni/CST 1510 /My_Aplication/database/cyber_incidents.csv")

print(df.head())
# Out:
#          date   incident_type  severity         status  \
# 0  2024-10-30     Data Breach    Medium  Investigating
# 1  2025-05-15            DDoS    Medium         Closed
# 2  2024-09-08  Insider Threat  Critical       Resolved
# 3  2025-09-17        Phishing    Medium       Resolved
# 4  2024-12-14            DDoS  Critical           Open
#
#                     description reported_by           created_at
# 0   Unauthorized access attempt       alice  2024-06-03 11:54:44
# 1       Phishing email reported         bob  2024-09-30 04:37:06
# 2     Malware execution blocked       alice  2024-09-14 03:43:17
# 3  Suspicious activity detected         bob  2025-01-28 01:46:12
# 4     Malware execution blocked         bob  2025-03-27 16:39:10

# %%
print(df["status"].unique())
# Out:
# ['Investigating' 'Closed' 'Resolved' 'Open']
