# %%
import pandas as pd

df = pd.read_csv("/Users/stepanpelc/Desktop/Uni/CST 1510 /My_Aplication/database/datasets_metadata.csv")

print(df.head())
# Out:
#   dataset_name             category             source last_updated  \
# 0    dataset_1      Malware Samples  On-Prem Appliance   2023-12-03
# 1    dataset_2  Authentication Logs     Cloud Provider   2020-05-30
# 2    dataset_3      Malware Samples        SIEM Export   2024-03-02
# 3    dataset_4  Authentication Logs       Internal SOC   2022-01-23
# 4    dataset_5       System Metrics     Cloud Provider   2023-01-13
#
#    record_count  file_size_mb           created_at
# 0       2603372       4860.33  2021-12-11 00:00:00
# 1        439552       1482.81  2021-03-15 00:00:00
# 2       4097680       1458.11  2024-10-28 00:00:00
# 3        111686       4528.04  2024-07-09 00:00:00
# 4       3235653       3135.06  2021-10-22 00:00:00

# %%
print(df["severity"].unique())
# Out:
# ['Medium' 'Critical' 'Low' 'High']

# %%
print(df["date"].min())
print(df["date"].max())
# Out:
# 2023-11-18
# 2025-11-16

# %%
df = pd.read_csv("/Users/stepanpelc/Desktop/Uni/CST 1510 /My_Aplication/database/it_tickets.csv")

print(df.head())
# Out:
#     ticket_id  priority       status  category            subject  \
# 0  TKT-100000      High         Open    Access     Network outage
# 1  TKT-100001      High         Open   Network  Application crash
# 2  TKT-100002      High     Resolved    Access     Password reset
# 3  TKT-100003    Medium  In Progress  Security     Network outage
# 4  TKT-100004  Critical         Open    Access  Email malfunction
#
#                          description created_date resolved_date assigned_to  \
# 0     Issue reported: Network outage   2020-11-15           NaN         Bob
# 1  Issue reported: Application crash   2021-08-30           NaN        Ivan
# 2     Issue reported: Password reset   2021-03-12    2021-03-13       Diana
# 3     Issue reported: Network outage   2024-11-10           NaN        Ivan
# 4  Issue reported: Email malfunction   2020-12-02           NaN      Hannah
#
#             created_at
# 0  2020-11-15 00:00:00
# 1  2021-08-30 00:00:00
# 2  2021-03-12 00:00:00
# ...
